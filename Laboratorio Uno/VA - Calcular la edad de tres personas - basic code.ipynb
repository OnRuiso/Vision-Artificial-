# %% [markdown]
# ### TRABAJO:
#
# ##### Escribir un pequeño programa donde:
# 1. Se ingresa el año en curso.
# 2. Se ingresa el nombre y el año de nacimiento de tres personas.
# 3. Se calcula cuántos años cumplirán durante el año en curso.
# 4. Se imprime en pantalla.
# 5. El programa debe detectar errores en el tipo de datos ingresados por el usuario.
# 6. Debe presentarse un diagrama de flujo detallado del programa desarrollado

# %%
print('PROGRAMA PARA CALCULAR LA EDAD\n')
Aencurso=input("\nIngrese el año en curso: ")
try:
    Acur=int(Aencurso)
except:
    Acur = -1
while Acur < 0 :
    print('\nEl dato ingresado no corresponde al año en curso')
    Aencurso=input('Ingrese el año en curso: ')
    try:
        Acur = int(Aencurso)
    except:
        Acur = -1

nombre1=input('\nIngrese el nombre de la primera persona: ')
año1=input('Ingrese el año de nacimiento de la primera persona: ')
try:
    a1 = int(año1)
except:
    a1 = -1
while a1 < 0:
    print('\nEl dato del año de nacimiento ingresado no es correcto')
    año1=input('Ingrese el año de nacimiento de la primera persona: ')
    try:
        a1 = int(año1)
    except:
        a1 = -1
while a1 >= Acur:
    print('\nEl dato del año de nacimiento ingresado no es correcto')
    año1=input('Ingrese el año de nacimiento de la primera persona: ')
    try:
        a1 = int(año1)
    except:
        a1 = -1

nombre2=input('\nIngrese el nombre de la segunda persona: ')
año2=input('Ingrese el año de nacimiento de la segunda persona: ')
try:
    a2 = int(año2)
except:
    a2 = -1
while a2 < 0:
    print('\nEl dato del año de nacimiento ingresado no es correcto')
    año2=input('Ingrese el año de nacimiento de la segunda persona: ')
    try:
        a2 = int(año2)
    except:
        a2 = -1
while a2 >= Acur:
    print('\nEl dato del año de nacimiento ingresado no es correcto')
    año2=input('Ingrese el año de nacimiento de la segunda persona: ')
    try:
        a2 = int(año2)
    except:
        a2 = -1

nombre3=input('\nIngrese el nombre de la tercera persona: ')
año3=input('Ingrese el año de nacimiento de la tercera persona: ')
try:
    a3 = int(año3)
except:
    a3 = -1
while a3 < 0:
    print('\nEl dato del año de nacimiento ingresado no es correcto')
    año3=input('Ingrese el año de nacimiento de la tercera persona: ')
    try:
        a3 = int(año3)
    except:
        a3 = -1
while a3 >= Acur:
    print('\nEl dato del año de nacimiento ingresado no es correcto')
    año3=input('Ingrese el año de nacimiento de la primera persona: ')
    try:
        a3 = int(año3)
    except:
        a3 = -1

edad1 = Acur - a1
edad2 = Acur - a2
edad3 = Acur - a3
print("\n",nombre1," cumplirá ",edad1," años durante el transcurso del año ", Acur)
print(nombre2," cumplirá ",edad2," años durante el transcurso del año ", Acur)
print(nombre3," cumplirá ",edad3," años durante el transcurso del año ", Acur)
print("\nFin")
