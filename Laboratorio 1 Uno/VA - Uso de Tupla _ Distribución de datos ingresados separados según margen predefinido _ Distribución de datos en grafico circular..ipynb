# %% [markdown]
# # TRABAJO:
#
# ### Desarrolle un programa en donde se defina una tupla que contenga 10 edades de personas. El programa debe imprimir la cantidad de personas con edades superiores, inferiores e iguales a un número dado en años, ingresado por el usuario. Los resultados de esta distribución de edades deben mostrarse en un gráfico tipo torta.

# %%
print("Bienvenido al sistema de clasificacion de edades por Rangos")

#---------------------------------------------------------------------------------------------------------------
#                          Ingreso de las edades por parte de los Usuarios
################################################################################################################
print("-------------------------------------------------------\(°¬°)/ 1")
#---------------------------------------------------------------------------------------------------------------
edad1 = input("Ingrese su edad Persona Uno:  ")

try:
    PpP1 = int(edad1)
except:
    PpP1 = 'C'
   
    
while PpP1 == 'C'or PpP1 <=0 or PpP1>99:
    print("Esto no es un numero señorit@")
    edad1 = input("Ingrese su edad Persona Uno:  ")
    try:
        PpP1 = int(edad1)
    except:
        PpP1 = 'C'
                
edad11=int(edad1)

if edad11 > 0:
    print("Persona uno edad: ", edad11)
#---------------------------------------------------------------------------------------------------------------   
print("Siguiente usuario por favor")
print("-------------------------------------------------------\(°¬°)/ 2")
#---------------------------------------------------------------------------------------------------------------   
edad2 = input("Ingrese su edad Persona Dos:  ")

try:
    PpP2 = int(edad2)
except:
    PpP2 = 'C'
   
    
while PpP2 == 'C'or PpP2 <=0 or PpP2>99:
    print("Esto no es un numero señorit@")
    edad2 = input("Ingrese su edad Persona Dos:  ")
    try:
        PpP2 = int(edad2)
    except:
        PpP2 = 'C'
        
        
edad22=int(edad2)

if edad22 > 0:
    print("Persona dos edad: ", edad22)
#---------------------------------------------------------------------------------------------------------------    
print("Siguiente usuario por favor")
print("-------------------------------------------------------\(°¬°)/ 3")
#---------------------------------------------------------------------------------------------------------------   
edad3 = input("Ingrese su edad Persona Tres:  ")

try:
    PpP3 = int(edad3)
except:
    PpP3 = 'C'
   
    
while PpP3 == 'C'or PpP3 <=0 or PpP3>99:
    print("Esto no es un numero señorit@")
    edad3 = input("Ingrese su edad Persona Tres:  ")
    try:
        PpP3 = int(edad3)
    except:
        PpP3 = 'C'
        
        
edad33=int(edad3)

if edad33 > 0:
    print("Persona tres edad: ", edad33)
#---------------------------------------------------------------------------------------------------------------
print("Siguiente usuario por favor")
print("-------------------------------------------------------\(°¬°)/ 4")
#---------------------------------------------------------------------------------------------------------------   
edad4 = input("Ingrese su edad Persona Cuatro:  ")

try:
    PpP4 = int(edad4)
except:
    PpP4 = 'C'
   
    
while PpP4 == 'C'or PpP4 <=0 or PpP4>99:
    print("Esto no es un numero señorit@")
    edad4 = input("Ingrese su edad Persona Cuatro:  ")
    try:
        PpP4 = int(edad4)
    except:
        PpP4 = 'C'
              
edad44=int(edad4)

if edad44 > 0:
    print("Persona cuatro edad: ", edad44)
#---------------------------------------------------------------------------------------------------------------    
print("Siguiente usuario por favor")
print("-------------------------------------------------------\(°¬°)/ 5")
#---------------------------------------------------------------------------------------------------------------   
edad5 = input("Ingrese su edad Persona Cinco:  ")

try:
    PpP5 = int(edad5)
except:
    PpP5 = 'C'
   
    
while PpP5 == 'C'or PpP5 <=0 or PpP5>99:
    print("Esto no es un numero señorit@")
    edad5 = input("Ingrese su edad Persona Cinco:  ")
    try:
        PpP5 = int(edad5)
    except:
        PpP5 = 'C'
    
        
edad55=int(edad5)

if edad55 > 0:
    print("Persona cinco edad: ", edad55)
#---------------------------------------------------------------------------------------------------------------
print("Siguiente usuario por favor")
print("-------------------------------------------------------\(°¬°)/ 6")
#---------------------------------------------------------------------------------------------------------------   
edad6 = input("Ingrese su edad Persona Sexta:  ")

try:
    PpP6 = int(edad6)
except:
    PpP6 = 'C'
   
    
while PpP6 == 'C'or PpP6 <=0 or PpP6>99:
    print("Esto no es un numero señorit@")
    edad6 = input("Ingrese su edad Persona Sexta:  ")
    try:
        PpP6 = int(edad6)
    except:
        PpP6 = 'C'
        
        
edad66=int(edad6)

if edad66 > 0:
    print("Persona seis edad: ", edad66)
#---------------------------------------------------------------------------------------------------------------
print("Siguiente usuario por favor")
print("-------------------------------------------------------\(°¬°)/ 7")
#---------------------------------------------------------------------------------------------------------------   
edad7 = input("Ingrese su edad Persona Septima:  ")

try:
    PpP7 = int(edad7)
except:
    PpP7 = 'C'
   
    
while PpP7 == 'C'or PpP7 <=0 or PpP7>99:
    print("Esto no es un numero señorit@")
    edad7 = input("Ingrese su edad Persona Septima:  ")
    try:
        PpP7 = int(edad7)
    except:
        PpP7 = 'C'
        
        
edad77=int(edad7)

if edad77 > 0:
    print("Persona siete edad: ", edad77)
#---------------------------------------------------------------------------------------------------------------    
print("Siguiente usuario por favor")
print("-------------------------------------------------------\(°¬°)/ 8")
#---------------------------------------------------------------------------------------------------------------   
edad8 = input("Ingrese su edad Persona Octava:  ")

try:
    PpP8 = int(edad8)
except:
    PpP8 = 'C'
   
    
while PpP8 == 'C'or PpP8 <=0 or PpP8>99:
    print("Esto no es un numero señorit@")
    edad8 = input("Ingrese su edad Persona Octava:  ")
    try:
        PpP8 = int(edad8)
    except:
        PpP8 = 'C'

        
edad88=int(edad8)

if edad88 > 0:
    print("Persona ocho edad: ", edad88)
#----------------------------------------------------------------------------------------------------------------- 
print("Siguiente usuario por favor")
print("-------------------------------------------------------\(°¬°)/ 9")
#---------------------------------------------------------------------------------------------------------------   
edad9 = input("Ingrese su edad Persona Novena:  ")

try:
    PpP9 = int(edad9)
except:
    PpP9 = 'C'
   
    
while PpP9 == 'C'or PpP9 <=0 or PpP9 >99:
    print("Esto no es un numero señorit@")
    edad9 = input("Ingrese su edad Persona Novena:  ")
    try:
        PpP9 = int(edad9)
    except:
        PpP9 = 'C'
               
edad99=int(edad9)

if edad99 > 0:
    print("Persona nueve edad: ", edad99)
#-----------------------------------------------------------------------------------------------------------------    
print("Siguiente usuario por favor")
print("-------------------------------------------------------\(°¬°)/ 10")
#---------------------------------------------------------------------------------------------------------------   
edad10 = input("Ingrese su edad Persona Decima:  ")

try:
    PpP10 = int(edad10)
except:
    PpP10 = 'C'
   
    
while PpP10 == 'C'or PpP10 <=0 or PpP10>99:
    print("Esto no es un numero señorit@")
    edad10 = input("Ingrese su edad Persona Decima:  ")
    try:
        PpP10 = int(edad10)
    except:
        PpP10 = 'C'
        
        
edad100=int(edad10)

if edad100 > 0:
    print("Persona dies edad: ", edad100)
#-----------------------------------------------------------------------------------------------------------------   
    


#-----------------------------------------------------------------------------------------------------------------
#              Parte del Codigo para Rango
##################################################################################################################    
Rango = input("Ingrese el valor con el que quiere comparar las edades")

try:
    CCC = int(Rango)
except:
    CCC = 'C'
   
    
while CCC == 'C'or CCC <=0 or CCC>99:
    print("Esto no es un numero señorit@")
    Rango = input("Ingrese un rango para comparar:  ")
    try:
        CCC = int(Rango)
    except:
        CCC = 'C'
    
        
Baby=int(Rango)

if Baby > 0:
    print("Se iniciara la camparacion con el siguiente numero: ", Baby)
#---------------------------------------------------------------------------------------------------------------
#                      Agrupacion de edades y grafico de Pie
################################################################################################################    
GrupoA = 0
GrupoB = 0
GrupoC =0

if edad11 < Baby:
    GrupoA = GrupoA + 1
if edad11 > Baby:
    GrupoB = GrupoB + 1
if edad11 == Baby:
    GrupoC = GrupoC + 1

if edad22 < Baby:
    GrupoA = GrupoA + 1
if edad22 > Baby:
    GrupoB = GrupoB + 1
if edad22 == Baby:
    GrupoC = GrupoC + 1

if edad33 < Baby:
    GrupoA = GrupoA + 1
if edad33 > Baby:
    GrupoB = GrupoB + 1
if edad33 == Baby:
    GrupoC = GrupoC + 1

if edad44 < Baby:
    GrupoA = GrupoA + 1
if edad44 > Baby:
    GrupoB = GrupoB + 1
if edad44 == Baby:
    GrupoC = GrupoC + 1

if edad55 < Baby:
    GrupoA = GrupoA + 1
if edad55 > Baby:
    GrupoB = GrupoB + 1
if edad55== Baby:
    GrupoC = GrupoC + 1
    
if edad66 < Baby:
    GrupoA = GrupoA + 1
if edad66 > Baby:
    GrupoB = GrupoB + 1
if edad66 == Baby:
    GrupoC = GrupoC + 1

if edad77 < Baby:
    GrupoA = GrupoA + 1
if edad77 > Baby:
    GrupoB = GrupoB + 1
if edad77 == Baby:
    GrupoC = GrupoC + 1
    
if edad88 < Baby:
    GrupoA = GrupoA + 1
if edad88 > Baby:
    GrupoB = GrupoB + 1
if edad88 == Baby:
    GrupoC = GrupoC + 1

if edad99 < Baby:
    GrupoA = GrupoA + 1
if edad99 > Baby:
    GrupoB = GrupoB + 1
if edad99 == Baby:
    GrupoC = GrupoC + 1

if edad100 < Baby:
    GrupoA = GrupoA + 1
if edad100 > Baby:
    GrupoB = GrupoB + 1
if edad100 == Baby:
    GrupoC = GrupoC + 1
    
contenedor= 10 , "Esta es la TUPLA" , edad11 , edad22 , edad33 , edad44 , edad55 , edad66 , edad77 , edad88 , edad99 , edad100 
    
print("El Total de Menores al Rango de edad dado es: ", GrupoA)
print("El Total de Mayores al Rango de edad dado es: ", GrupoB)
print("El Total de Iguales al Rango de edad dado es: ", GrupoC)

import matplotlib.pyplot as plt

labels = 'Menores 7u7','Mayores ._.?','Iguales'
sizes = [GrupoA , GrupoB , GrupoC]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

print("Las edades de los Usuarios son: ")
print( edad11 , edad22 , edad33 , edad44 , edad55 , edad66 , edad77 , edad88 , edad99 , edad100 )
print(contenedor)
#---------------------------------------------------------------------------------------------------------------
#                         Rango de edades por porcentajes????
################################################################################################################    
#edadesTotales = (edad11 , edad22)


#Total = edad11 + edad22
#PorcentajeUno = ((edad11*1)/Total)*100
#PorcentajeDos = ((edad22*1)/Total)*100

#import matplotlib.pyplot as plt

#labels = 'One','Two'
#sizes = [edad11 , edad22]

#fig1, ax1 = plt.subplots()
#ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
#        shadow=True, startangle=90)
#ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
 
#plt.show()
# Out:
# Bienvenido al sistema de clasificacion de edades por Rangos
# -------------------------------------------------------\(°¬°)/ 1
# Ingrese su edad Persona Uno:  23
# Persona uno edad:  23
# Siguiente usuario por favor
# -------------------------------------------------------\(°¬°)/ 2
# Ingrese su edad Persona Dos:  22
# Persona dos edad:  22
# Siguiente usuario por favor
# -------------------------------------------------------\(°¬°)/ 3
# Ingrese su edad Persona Tres:  56
# Persona tres edad:  56
# Siguiente usuario por favor
# -------------------------------------------------------\(°¬°)/ 4
# Ingrese su edad Persona Cuatro:  45
# Persona cuatro edad:  45
# Siguiente usuario por favor
# -------------------------------------------------------\(°¬°)/ 5
# Ingrese su edad Persona Cinco:  12
# Persona cinco edad:  12
# Siguiente usuario por favor
# -------------------------------------------------------\(°¬°)/ 6
# Ingrese su edad Persona Sexta:  78
# Persona seis edad:  78
# ...
